# %%
import numpy as np
import pandas as pd
import pandas as pd
import seaborn as sns

import missingno as mn

# %matplotlib inline
import zipfile
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

# %%
# load in the file
# application_train.csv
app_train = pd.read_csv('/Users/amy/Desktop/project data/application_train.csv.zip', compression='zip', header=0, sep=',', quotechar='"')
app_train.head()

print(app_train.shape)
# Out:
# (307511, 122)

# %%
# Percentage of missing value in each column
(app_train.isnull().sum() * 100/ len(app_train)).sort_values(ascending=False).head(70)
# Out:
# COMMONAREA_MEDI                 69.872297
# COMMONAREA_AVG                  69.872297
# COMMONAREA_MODE                 69.872297
# NONLIVINGAPARTMENTS_MODE        69.432963
# NONLIVINGAPARTMENTS_MEDI        69.432963
# NONLIVINGAPARTMENTS_AVG         69.432963
# FONDKAPREMONT_MODE              68.386172
# LIVINGAPARTMENTS_MEDI           68.354953
# LIVINGAPARTMENTS_MODE           68.354953
# LIVINGAPARTMENTS_AVG            68.354953
# FLOORSMIN_MEDI                  67.848630
# FLOORSMIN_MODE                  67.848630
# FLOORSMIN_AVG                   67.848630
# YEARS_BUILD_MEDI                66.497784
# YEARS_BUILD_AVG                 66.497784
# YEARS_BUILD_MODE                66.497784
# OWN_CAR_AGE                     65.990810
# LANDAREA_MODE                   59.376738
# LANDAREA_AVG                    59.376738
# LANDAREA_MEDI                   59.376738
# BASEMENTAREA_MEDI               58.515956
# BASEMENTAREA_AVG                58.515956
# ...

# %%
# missing value per row 

app_train.isnull().sum(axis=1).sort_values(ascending=False).head(151000)
# Out:
# 133770    61
# 244833    61
# 150206    61
# 69707     61
# 269786    61
# 269492    61
# 116937    61
# 185713    61
# 197736    61
# 87399     60
# 7077      60
# 115346    60
# 201306    60
# 146561    60
# 68013     60
# 53941     60
# 48839     60
# 36899     60
# 54457     60
# 241006    60
# 290495    60
# 127942    60
# 260125    60
# 109581    60
# 266184    60
# 172595    60
# 271341    60
# 258474    60
# 12087     60
# 193598    59
#           ..
# 266835    41
# 128729    41
# 146368    41
# 207706    41
# 203605    41
# 213412    41
# 185254    41
# 105472    41
# 163878    41
# 184473    41
# 94411     41
# 300047    41
# 40219     41
# 124408    41
# 102593    41
# 216108    41
# 88238     41
# 297451    41
# 238178    41
# 122200    41
# 99633     41
# 85507     41
# 238723    41
# 238719    41
# 191553    41
# 229483    41
# 158310    41
# 158098    41
# 158339    41
# 146401    41
# Length: 151000, dtype: int64

# %%
# visualize the missing value
sns.heatmap(app_train.isnull(), cbar=False)
plt.show()

# %%
# Oversampling on the class/target 
# imbalance class 

app_train['TARGET'].astype(int).plot.hist()

# %%
# Encoding Categorical Variables  ??

# %%
# POS_CASH.csv 
pos_cash = pd.read_csv('/Users/amy/Desktop/project data/POS_CASH_balance.csv.zip', compression='zip', header=0, sep=',', quotechar='"')
print(pos_cash.shape)+
# Out:
# (10001358, 8)

# %%
# Percentage of missing value in each column
print((pos_cash.isnull().sum() * 100/ len(app_train)).sort_values(ascending=False))

# 
pos_cash.head(5)

# Filling in the missing value with mean (CNT_INSTALMENT_FUTURE and CNT_INSTALMENT )
pos_cash['CNT_INSTALMENT_FUTURE'].fillna(pos_cash['CNT_INSTALMENT_FUTURE'].mean(), inplace=True)
pos_cash['CNT_INSTALMENT'].fillna(pos_cash['CNT_INSTALMENT'].mean(), inplace=True)

# export the excel 
pos_cash.to_csv('pos_cash_NoMissing.csv')
# Out:
# SK_DPD_DEF               0.0
# SK_DPD                   0.0
# NAME_CONTRACT_STATUS     0.0
# CNT_INSTALMENT_FUTURE    0.0
# CNT_INSTALMENT           0.0
# MONTHS_BALANCE           0.0
# SK_ID_CURR               0.0
# SK_ID_PREV               0.0
# dtype: float64

# %%
# installments_payments.csv 
install_payment = pd.read_csv('/Users/amy/Desktop/project data/installments_payments.csv.zip', compression='zip', header=0, sep=',', quotechar='"')
print(install_payment.shape)
# Out:
# (13605401, 8)

# %%
# # Percentage of missing value in each column
# # This file doesn't have missing value
print((install_payment.isnull().sum() * 100/ len(app_train)).sort_values(ascending=False))

# install_payment.head()

# # Filling in the missing value with mean 
install_payment['AMT_PAYMENT'].fillna(install_payment['AMT_PAYMENT'].mean(), inplace=True)
install_payment['DAYS_ENTRY_PAYMENT'].fillna(install_payment['DAYS_ENTRY_PAYMENT'].mean(), inplace=True)
print((install_payment.isnull().sum() * 100/ len(app_train)).sort_values(ascending=False))

# export the excel 
install_payment.to_csv('installments_payments_NoMissing.csv')
# Out:
# AMT_PAYMENT               0.0
# AMT_INSTALMENT            0.0
# DAYS_ENTRY_PAYMENT        0.0
# DAYS_INSTALMENT           0.0
# NUM_INSTALMENT_NUMBER     0.0
# NUM_INSTALMENT_VERSION    0.0
# SK_ID_CURR                0.0
# SK_ID_PREV                0.0
# dtype: float64

# %%
# Out:
# 0          0.0
# 1          1.0
# 2          0.0
# 3          1.0
# 4          0.0
# 5          0.0
# 6          1.0
# 7          1.0
# 8          3.0
# 9          3.0
# 10         5.0
# 11         2.0
# 12         1.0
# 13         0.0
# 14         0.0
# 15         0.0
# 16         1.0
# 17         0.0
# 18         0.0
# 19         1.0
# 20         3.0
# 21         0.0
# 22         1.0
# 23         5.0
# 24         0.0
# 25         0.0
# 26         1.0
# 27         2.0
# 28         0.0
# 29         0.0
#           ...
# 3840282    0.0
# 3840283    0.0
# 3840284    0.0
# 3840285    0.0
# 3840286    0.0
# 3840287    2.0
# 3840288    2.0
# 3840289    0.0
# 3840290    0.0
# 3840291    0.0
# 3840292    1.0
# 3840293    0.0
# 3840294    0.0
# 3840295    4.0
# 3840296    0.0
# 3840297    0.0
# 3840298    0.0
# 3840299    2.0
# 3840300    2.0
# 3840301    1.0
# 3840302    0.0
# 3840303    NaN
# 3840304    0.0
# 3840305    0.0
# 3840306    NaN
# 3840307    NaN
# 3840308    0.0
# ...

# %%
# credit_card_balance.csv
creditcard_balance = pd.read_csv('/Users/amy/Desktop/project data/credit_card_balance.csv.zip', compression='zip', header=0, sep=',', quotechar='"')
print(creditcard_balance.shape)

# Percentage of missing value in each column
# This file doesn't have missing value
print((creditcard_balance.isnull().sum() * 100/ len(app_train)).sort_values(ascending=False))

# Filling in the missing value with mean 
creditcard_balance['AMT_PAYMENT_CURRENT'].fillna(creditcard_balance['AMT_PAYMENT_CURRENT'].mean(), inplace=True)
creditcard_balance['AMT_DRAWINGS_OTHER_CURRENT'].fillna(creditcard_balance['AMT_DRAWINGS_OTHER_CURRENT'].mean(), inplace=True)
creditcard_balance['CNT_DRAWINGS_POS_CURRENT'].fillna(creditcard_balance['CNT_DRAWINGS_POS_CURRENT'].mean(), inplace=True)
creditcard_balance['CNT_DRAWINGS_OTHER_CURRENT'].fillna(creditcard_balance['CNT_DRAWINGS_OTHER_CURRENT'].mean(), inplace=True)
creditcard_balance['AMT_DRAWINGS_ATM_CURRENT'].fillna(creditcard_balance['AMT_DRAWINGS_ATM_CURRENT'].mean(), inplace=True)
creditcard_balance['AMT_DRAWINGS_ATM_CURRENT'].fillna(creditcard_balance['AMT_DRAWINGS_ATM_CURRENT'].mean(), inplace=True)

creditcard_balance['AMT_DRAWINGS_POS_CURRENT'].fillna(creditcard_balance['AMT_DRAWINGS_POS_CURRENT'].mean(), inplace=True)
creditcard_balance['CNT_INSTALMENT_MATURE_CUM'].fillna(creditcard_balance['CNT_INSTALMENT_MATURE_CUM'].mean(), inplace=True)
creditcard_balance['AMT_INST_MIN_REGULARITY'].fillna(creditcard_balance['AMT_INST_MIN_REGULARITY'].mean(), inplace=True)
creditcard_balance['CNT_DRAWINGS_ATM_CURRENT'].fillna(creditcard_balance['CNT_DRAWINGS_ATM_CURRENT'].mean(), inplace=True)

print((creditcard_balance.isnull().sum() * 100/ len(app_train)).sort_values(ascending=False))

# print((install_payment.isnull().sum() * 100/ len(app_train)).sort_values(ascending=False))
# # export the excel 
creditcard_balance.to_csv('credit_card_balance_NoMissing.csv')

# %%
# Out:
# AMT_PAYMENT_CURRENT           249.743261
# AMT_DRAWINGS_OTHER_CURRENT    243.833879
# CNT_DRAWINGS_POS_CURRENT      243.833879
# CNT_DRAWINGS_OTHER_CURRENT    243.833879
# CNT_DRAWINGS_ATM_CURRENT      243.833879
# AMT_DRAWINGS_ATM_CURRENT      243.833879
# AMT_DRAWINGS_POS_CURRENT      243.833879
# CNT_INSTALMENT_MATURE_CUM      99.260189
# AMT_INST_MIN_REGULARITY        99.260189
# SK_DPD_DEF                      0.000000
# SK_ID_CURR                      0.000000
# MONTHS_BALANCE                  0.000000
# AMT_BALANCE                     0.000000
# AMT_CREDIT_LIMIT_ACTUAL         0.000000
# AMT_DRAWINGS_CURRENT            0.000000
# AMT_PAYMENT_TOTAL_CURRENT       0.000000
# SK_DPD                          0.000000
# AMT_RECEIVABLE_PRINCIPAL        0.000000
# AMT_RECIVABLE                   0.000000
# AMT_TOTAL_RECEIVABLE            0.000000
# CNT_DRAWINGS_CURRENT            0.000000
# NAME_CONTRACT_STATUS            0.000000
# SK_ID_PREV                      0.000000
# ...

# %%
# load in the file
bureau = pd.read_csv('C:/Users/mouni/Downloads/Sem 2/Project/Dataset/bureau.csv', header=0, sep=',', quotechar='"')
bureau.head()
# Out:
#    SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 0      215354       5714462        Closed      currency 1         -497
# 1      215354       5714463        Active      currency 1         -208
# 2      215354       5714464        Active      currency 1         -203
# 3      215354       5714465        Active      currency 1         -203
# 4      215354       5714466        Active      currency 1         -629
#
#    CREDIT_DAY_OVERDUE  DAYS_CREDIT_ENDDATE  DAYS_ENDDATE_FACT  \
# 0                   0               -153.0             -153.0
# 1                   0               1075.0                NaN
# 2                   0                528.0                NaN
# 3                   0                  NaN                NaN
# 4                   0               1197.0                NaN
#
#    AMT_CREDIT_MAX_OVERDUE  CNT_CREDIT_PROLONG  AMT_CREDIT_SUM  \
# 0                     NaN                   0         91323.0
# ...

# %%
# Percentage of missing value in each column
(bureau.isnull().sum() * 100/ len(bureau)).sort_values(ascending=False).head(60)
# Out:
# AMT_ANNUITY               71.473490
# AMT_CREDIT_MAX_OVERDUE    65.513264
# DAYS_ENDDATE_FACT         36.916958
# AMT_CREDIT_SUM_LIMIT      34.477415
# AMT_CREDIT_SUM_DEBT       15.011932
# DAYS_CREDIT_ENDDATE        6.149573
# AMT_CREDIT_SUM             0.000757
# CREDIT_TYPE                0.000000
# AMT_CREDIT_SUM_OVERDUE     0.000000
# CNT_CREDIT_PROLONG         0.000000
# DAYS_CREDIT_UPDATE         0.000000
# CREDIT_DAY_OVERDUE         0.000000
# DAYS_CREDIT                0.000000
# CREDIT_CURRENCY            0.000000
# CREDIT_ACTIVE              0.000000
# SK_ID_BUREAU               0.000000
# SK_ID_CURR                 0.000000
# dtype: float64

# %%
# visualize the missing value
bureau.isnull().sum().plot(kind='bar')

# %%
mn.matrix(bureau)

# %%
# missing value per row 

bureau.isnull().sum(axis=1).sort_values(ascending=False).head(151000)

# Filling in the missing value with mean (CNT_INSTALMENT_FUTURE and CNT_INSTALMENT )
bureau['AMT_ANNUITY'].fillna(bureau['AMT_ANNUITY'].mean(), inplace=True)
bureau['AMT_CREDIT_MAX_OVERDUE'].fillna(bureau['AMT_CREDIT_MAX_OVERDUE'].mean(), inplace=True)
bureau['DAYS_ENDDATE_FACT'].fillna(bureau['DAYS_ENDDATE_FACT'].mean(), inplace=True)
bureau['AMT_CREDIT_SUM_LIMIT'].fillna(bureau['AMT_CREDIT_SUM_LIMIT'].mean(), inplace=True)
bureau['AMT_CREDIT_SUM_DEBT'].fillna(bureau['AMT_CREDIT_SUM_DEBT'].mean(), inplace=True)
bureau['DAYS_CREDIT_ENDDATE'].fillna(bureau['DAYS_CREDIT_ENDDATE'].mean(), inplace=True)
bureau['AMT_CREDIT_SUM'].fillna(bureau['AMT_CREDIT_SUM'].mean(), inplace=True)

# export the excel 
bureau.to_csv('bureau_NoMissing.csv')

# %%
# load in the file
bureau_balance = pd.read_csv('C:/Users/mouni/Downloads/Sem 2/Project/Dataset/bureau_balance.csv', header=0, sep=',', quotechar='"')
bureau_balance.head()
# Out:
#    SK_ID_BUREAU  MONTHS_BALANCE STATUS
# 0       5715448               0      C
# 1       5715448              -1      C
# 2       5715448              -2      C
# 3       5715448              -3      C
# 4       5715448              -4      C

# %%
# Percentage of missing value in each column
(bureau_balance.isnull().sum() * 100/ len(bureau_balance)).sort_values(ascending=False).head(60)
# Out:
# STATUS            0.0
# MONTHS_BALANCE    0.0
# SK_ID_BUREAU      0.0
# dtype: float64

# %%
# visualize the missing value
bureau_balance.isnull().sum().plot(kind='bar')

# %%
mn.matrix(bureau_balance)

# %%
# load in the file
previous_application = pd.read_csv('C:/Users/mouni/Downloads/Sem 2/Project/Dataset/previous_application.csv', header=0, sep=',', quotechar='"')
previous_application.head()
# Out:
#    SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION  \
# 0     2030495      271877     Consumer loans     1730.430          17145.0
# 1     2802425      108129         Cash loans    25188.615         607500.0
# 2     2523466      122040         Cash loans    15060.735         112500.0
# 3     2819243      176158         Cash loans    47041.335         450000.0
# 4     1784265      202054         Cash loans    31924.395         337500.0
#
#    AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE WEEKDAY_APPR_PROCESS_START  \
# 0     17145.0               0.0          17145.0                   SATURDAY
# 1    679671.0               NaN         607500.0                   THURSDAY
# 2    136444.5               NaN         112500.0                    TUESDAY
# 3    470790.0               NaN         450000.0                     MONDAY
# 4    404055.0               NaN         337500.0                   THURSDAY
#
# ...

# %%
# Percentage of missing value in each column
(previous_application.isnull().sum() * 100/ len(previous_application)).sort_values(ascending=False).head(60)
# Out:
# RATE_INTEREST_PRIVILEGED       99.643698
# RATE_INTEREST_PRIMARY          99.643698
# RATE_DOWN_PAYMENT              53.636480
# AMT_DOWN_PAYMENT               53.636480
# NAME_TYPE_SUITE                49.119754
# DAYS_TERMINATION               40.298129
# NFLAG_INSURED_ON_APPROVAL      40.298129
# DAYS_FIRST_DRAWING             40.298129
# DAYS_FIRST_DUE                 40.298129
# DAYS_LAST_DUE_1ST_VERSION      40.298129
# DAYS_LAST_DUE                  40.298129
# AMT_GOODS_PRICE                23.081773
# AMT_ANNUITY                    22.286665
# CNT_PAYMENT                    22.286366
# PRODUCT_COMBINATION             0.020716
# AMT_CREDIT                      0.000060
# SK_ID_CURR                      0.000000
# NAME_CONTRACT_TYPE              0.000000
# WEEKDAY_APPR_PROCESS_START      0.000000
# HOUR_APPR_PROCESS_START         0.000000
# FLAG_LAST_APPL_PER_CONTRACT     0.000000
# NFLAG_LAST_APPL_IN_DAY          0.000000
# AMT_APPLICATION                 0.000000
# ...

# %%
# visualize the missing value
previous_application.isnull().sum().plot(kind='bar')

# %%
mn.matrix(previous_application)
# Out:
# 0                      NaN
# 1            Unaccompanied
# 2          Spouse, partner
# 3                      NaN
# 4                      NaN
# 5                   Family
# 6                      NaN
# 7                      NaN
# 8                      NaN
# 9                      NaN
# 10           Unaccompanied
# 11           Unaccompanied
# 12           Unaccompanied
# 13           Unaccompanied
# 14                     NaN
# 15           Unaccompanied
# 16           Unaccompanied
# 17           Unaccompanied
# 18           Unaccompanied
# 19                     NaN
# 20           Unaccompanied
# 21                     NaN
# 22                     NaN
# 23                     NaN
# 24                     NaN
# 25           Unaccompanied
# 26                     NaN
# 27                     NaN
# 28                  Family
# 29                     NaN
#                 ...
# 1670184      Unaccompanied
# 1670185                NaN
# 1670186                NaN
# ...

# %%
# missing value per row 

previous_application.isnull().sum(axis=1).sort_values(ascending=False).head(151000)

# Filling in the missing value with mean (CNT_INSTALMENT_FUTURE and CNT_INSTALMENT)
previous_application['RATE_INTEREST_PRIVILEGED'].fillna(previous_application['RATE_INTEREST_PRIVILEGED'].mean(), inplace=True)
previous_application['RATE_INTEREST_PRIMARY'].fillna(previous_application['RATE_INTEREST_PRIMARY'].mean(), inplace=True)
previous_application['RATE_DOWN_PAYMENT'].fillna(previous_application['RATE_DOWN_PAYMENT'].mean(), inplace=True)
previous_application['AMT_DOWN_PAYMENT'].fillna(previous_application['AMT_DOWN_PAYMENT'].mean(), inplace=True)
previous_application['NAME_TYPE_SUITE'].fillna("NA", inplace=True)
previous_application['DAYS_TERMINATION'].fillna(previous_application['DAYS_TERMINATION'].mean(), inplace=True)
previous_application['NFLAG_INSURED_ON_APPROVAL'].fillna(previous_application['NFLAG_INSURED_ON_APPROVAL'].mean(), inplace=True)
previous_application['DAYS_FIRST_DRAWING'].fillna(previous_application['DAYS_FIRST_DRAWING'].mean(), inplace=True)
previous_application['DAYS_FIRST_DUE'].fillna(previous_application['DAYS_FIRST_DUE'].mean(), inplace=True)
previous_application['DAYS_LAST_DUE_1ST_VERSION'].fillna(previous_application['DAYS_LAST_DUE_1ST_VERSION'].mean(), inplace=True)
previous_application['DAYS_LAST_DUE'].fillna(previous_application['DAYS_LAST_DUE'].mean(), inplace=True)
previous_application['AMT_GOODS_PRICE'].fillna(previous_application['AMT_GOODS_PRICE'].mean(), inplace=True)
previous_application['AMT_ANNUITY'].fillna(previous_application['AMT_ANNUITY'].mean(), inplace=True)
previous_application['CNT_PAYMENT'].fillna(previous_application['CNT_PAYMENT'].mean(), inplace=True)
previous_application['PRODUCT_COMBINATION'].fillna(previous_application['PRODUCT_COMBINATION'].mean(), inplace=True)

# export the excel 
previous_application.to_csv('previous_application_NoMissing.csv')

# %%
# load in the file
sample_submission = pd.read_csv('C:/Users/mouni/Downloads/Sem 2/Project/Dataset/sample_submission.csv', header=0, sep=',', quotechar='"')
sample_submission.head()
# Out:
#    SK_ID_CURR  TARGET
# 0      100001     0.5
# 1      100005     0.5
# 2      100013     0.5
# 3      100028     0.5
# 4      100038     0.5

# %%
# Percentage of missing value in each column
(sample_submission.isnull().sum() * 100/ len(sample_submission)).sort_values(ascending=False).head(60)
# Out:
# TARGET        0.0
# SK_ID_CURR    0.0
# dtype: float64

# %%
# visualize the missing value
sample_submission.isnull().sum().plot(kind='bar')

# %%
mn.matrix(sample_submission)
